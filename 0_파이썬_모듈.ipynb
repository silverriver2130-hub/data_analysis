# %% [markdown]
# <a href="https://colab.research.google.com/github/silverriver2130-hub/data_analysis/blob/main/0_%ED%8C%8C%EC%9D%B4%EC%8D%AC_%EB%AA%A8%EB%93%88.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **1. 파일 종류 소개**
# 파이썬에서는 .ipynb 파일과 .py 파일 모두 파이썬 코드를 작성할 수 있지만, 사용 목적과 형식이 다릅니다.
#
# <img src='https://img1.daumcdn.net/thumb/R1280x0/?scode=mtistory2&fname=https%3A%2F%2Fblog.kakaocdn.net%2Fdna%2FdrIfzo%2FbtsNXXAs4OR%2FAAAAAAAAAAAAAAAAAAAAAKXuY-Nk2RM2WOnAirwaQfRsOIuU9d0p1hVXF51Jkx5U%2Fimg.png%3Fcredential%3DyqXZFxpELC7KVnFOS48ylbz2pIh7yKj8%26expires%3D1764514799%26allow_ip%3D%26allow_referer%3D%26signature%3DQzn%252B18eHDU3yyVv%252BVTeV8qPsU%252B8%253D'>

# %% [markdown]
# # **2. 모듈**
# 파이썬에서 모듈을 만들려면 간단히 .py 확장자를 가진 파일에 코드를 작성하면 됩니다. 모듈은 단순한 함수 뿐만 아니라 변수, 클래스 등도 포함할 수 있으며, 다른 스크립트에서 import 구문을 사용하여 가져올 수 있습니다.

# %%
import math_tools # math_tools 안에 있는 코드를 가져다 사용할수 있다 (메모리에 올라감)

# %%
math_tools.PI
# Out:
# 3.141592653589793

# %%
print(math_tools.add(5, 8))
print(math_tools.subtract((5, 8)))
# Out:
# 13

# %%
circle = math_tools.Circle(4) # math_tools 안에 있는 코드를 가져오는 것이기 때문에 앞에 math_tools. 붙여야 한다
print(circle.area())
# Out:
# 50.26548245743669

# %%
from math_tools import PI, Circle # 안에 있는 내용을 그대로 쓸수 있음

# %%
print(PI)
circle = Circle(5)
print(circle.area())
# Out:
# 3.141592653589793
# 78.53981633974483

# %%
import math_tools as mt # math_tools를 mt로 대체할 수 있음

# %%
print(mt.PI)
print(mt.add(5, 3))
print(mt.subtract(5, 3))
circle = mt.Circle(5) # */
print(circle.area())
# Out:
# 3.141592653589793
# 8
# 2
# 78.53981633974483

# %%
# 서버 끊어지면 파일 날라감
# 코렙 파일에 올리지 말고 구글 드라이브에 올려서 구글 드라이브에 있는 모듈 꺼내서 사용하자
path = '/content/drive/MyDrive/AI 활용 멀티모달 MCP PJ 시즌 1/2. 데이터 분석/모듈'

import sys
print(sys.path) # 파이썬 시스템에 등록된 모듈들 (import하면 이 경로에서 필요한 모듈을 찾는다)
sys.path.append(path) # 구글 드라이브에 있는 모듈은 파이썬 시스템에 등록시킨후 사용해야 한다
# Out:
# ['/content', '/env/python', '/usr/lib/python312.zip', '/usr/lib/python3.12', '/usr/lib/python3.12/lib-dynload', '', '/usr/local/lib/python3.12/dist-packages', '/usr/lib/python3/dist-packages', '/usr/local/lib/python3.12/dist-packages/IPython/extensions', '/root/.ipython', '/content/drive/MyDrive/AI 활용 멀티모달 MCP PJ 시즌 1/2. 데이터 분석/모듈', '/content/drive/MyDrive/AI 활용 멀티모달 MCP PJ 시즌 1/2. 데이터 분석/모듈', '/content/drive/MyDrive/AI 활용 멀티모달 MCP PJ 시즌 1/2. 데이터 분석/모듈']

# %%
from math_tools import PI, Circle

print(PI)
circle = Circle(5)
print(circle.area())
# Out:
# 3.141592653589793
# 78.53981633974483

# %% [markdown]
# # **3. 패키지**
# 파이썬에서 패키지는 모듈들을 포함하고 있는 디렉터리입니다. 모듈은 파이썬 코드를 담고 있는 파일이며, 여러 모듈을 논리적으로 그룹화하려는 경우 패키지를 사용합니다. 패키지를 사용하면 관련된 기능들을 함께 묶어서 코드를 더욱 체계적으로 관리할 수 있습니다.
#
# ```
# my_package/
# │
# ├── __init__.py
# │
# ├── module_a.py
# │
# └── sub_package/
#     │
#     ├── __init__.py
#     └── module_b.py
#
# ```
#
# 패키지는 기본적으로 디렉터리와 그 안의 .py 파일들로 구성됩니다. 패키지를 구성하는 디렉터리 내에는 \_\_init\_\_.py라는 특별한 파일이 있어야 합니다. 이 파일은 해당 디렉터리가 파이썬 패키지임을 나타냅니다. \_\_init\_\_.py는 비워둘 수도 있고, 패키지 초기화 코드를 포함할 수도 있습니다. 또한 패키지 안에 다른 패키지(하위 패키지)를 포함할 수 있습니다. 이를 통해 복잡한 프로젝트의 코드를 여러 레벨의 디렉터리로 계층적으로 구성할 수 있습니다.

# %% [markdown]
# ### 패키지 만들기 실습
#
# ```
# shapes/
# │
# ├── __init__.py
# ├── circle.py
# └── rectangle.py
#
# ```

# %%
from shapes import circle, rectangle # 왜 에러남?

# %%
# circle 모듈의 함수 사용
print(circle.area(5))  # 원의 면적
print(circle.circumference(5))  # 원의 둘레

# rectangle 모듈의 함수 사용
print(rectangle.area(4, 6))  # 직사각형의 면적
print(rectangle.perimeter(4, 6))  # 직사각형의 둘레
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-3293632495.py in <cell line: 0>()
#       1 # circle 모듈의 함수 사용
# ----> 2 print(circle.area(5))  # 원의 면적
#       3 print(circle.circumference(5))  # 원의 둘레
#       4
#       5 # rectangle 모듈의 함수 사용
#
# AttributeError: module 'shapes.circle' has no attribute 'area'

# %%
from shapes.circle import area as circle_area
from shapes.rectangle import area as rectangle_area

print(circle_area(5))  # 원의 면적
print(rectangle_area(4, 6))  # 직사각형의 면적
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipython-input-2968396119.py in <cell line: 0>()
# ----> 1 from shapes.circle import area as circle_area
#       2 from shapes.rectangle import area as rectangle_area
#       3
#       4 print(circle_area(5))  # 원의 면적
#       5 print(rectangle_area(4, 6))  # 직사각형의 면적
#
# ImportError: cannot import name 'area' from 'shapes.circle' (/content/drive/MyDrive/AI 활용 멀티모달 MCP PJ 시즌 1/2. 데이터 분석/모듈/shapes/circle.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
